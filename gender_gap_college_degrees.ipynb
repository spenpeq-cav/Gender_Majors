# %% [markdown]
# # Visualizing The Gender Gap In College Degrees

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

women_degrees = pd.read_csv('percent-bachelors-degrees-women-usa.csv')
cb_dark_blue = (0/255,107/255,164/255)
cb_orange = (255/255, 128/255, 14/255)

stem_cats = ['Psychology', 'Biology', 'Math and Statistics', 'Physical Sciences', 'Computer Science', 'Engineering']
fig = plt.figure(figsize=(18, 3))

for sp in range(0,6):
    ax = fig.add_subplot(1,6,sp+1)
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[stem_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(stem_cats[sp])
    ax.tick_params(bottom="off", top="off", left="off", right="off")
    
    if sp == 0:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    elif sp == 5:
        ax.text(2005, 62, 'Men')
        ax.text(2001, 35, 'Women')

plt.show()

# %% [markdown]
# # Comparing Across All Degrees

# %%
stem_cats = ['Psychology', 'Biology', 'Math and Statistics', 'Physical Sciences', 'Computer Science', 'Engineering']
lib_arts_cats = ['Foreign Languages', 'English', 'Communications and Journalism', 'Art and Performance', 'Social Sciences and History']
other_cats = ['Health Professions', 'Public Administration', 'Education', 'Agriculture','Business', 'Architecture']

fig = plt.figure(figsize=(16, 20))

for sp in range(0,18,3):
    maj_index = int(sp/3)
    ax = fig.add_subplot(6,3,sp+1)
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[maj_index]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[stem_cats[maj_index]], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(stem_cats[maj_index])
    ax.tick_params(bottom="off", top="off", left="off", right="off")
    
    if sp == 0:
        ax.text(2005, 84, 'Women')
        ax.text(2007, 12, 'Men')
    elif sp == 15:
        ax.text(2007, 89, 'Men')
        ax.text(2005, 7, 'Women')
        


for sp in range(2,17,3):
    maj_index = int((sp-2)/3)
    ax = fig.add_subplot(6,3,sp)
    ax.plot(women_degrees['Year'], women_degrees[lib_arts_cats[maj_index]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[lib_arts_cats[maj_index]], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(lib_arts_cats[maj_index])
    ax.tick_params(bottom="off", top="off", left="off", right="off")
    
    
    if maj_index == 0:
        ax.text(2005, 78, 'Women')
        ax.text(2007, 18, 'Men')
    
        
for sp in range(3,20,3):
    maj_index = int((sp-3) / 3)
    ax = fig.add_subplot(6,3,sp)
    ax.plot(women_degrees['Year'], women_degrees[other_cats[maj_index]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[other_cats[maj_index]], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(other_cats[maj_index])
    ax.tick_params(bottom="off", top="off", left="off", right="off")
    
    if maj_index == 0:
        ax.text(2003, 90, 'Women')
        ax.text(2005, 5, 'Men')
    elif maj_index == 5:
        ax.text(2005, 62, 'Men')
        ax.text(2003, 33, 'Women')
        
        
plt.show()

# %% [markdown]
# # Hiding x-axis Labels

# %%
fig = plt.figure(figsize=(16, 20))

for sp in range(0,18,3):
    maj_index = int(sp/3)
    ax = fig.add_subplot(6,3,sp+1)
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[maj_index]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[stem_cats[maj_index]], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(stem_cats[maj_index])
    ax.tick_params(bottom="off", top="off", left="off", right="off", labelbottom='off')
    
    
    if sp == 0:
        ax.text(2005, 84, 'Women')
        ax.text(2007, 12, 'Men')
    elif sp == 15:
        ax.text(2007, 89, 'Men')
        ax.text(2005, 7, 'Women')
        ax.tick_params(labelbottom='on')


for sp in range(2,17,3):
    maj_index = int((sp-2)/3)
    ax = fig.add_subplot(6,3,sp)
    ax.plot(women_degrees['Year'], women_degrees[lib_arts_cats[maj_index]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[lib_arts_cats[maj_index]], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(lib_arts_cats[maj_index])
    ax.tick_params(bottom="off", top="off", left="off", right="off", labelbottom='off')
    
    
    if maj_index == 0:
        ax.text(2005, 78, 'Women')
        ax.text(2007, 18, 'Men')
    elif maj_index == 4:
        ax.tick_params(labelbottom='on')
        
for sp in range(3,20,3):
    maj_index = int((sp-3) / 3)
    ax = fig.add_subplot(6,3,sp)
    ax.plot(women_degrees['Year'], women_degrees[other_cats[maj_index]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[other_cats[maj_index]], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(other_cats[maj_index])
    ax.tick_params(bottom="off", top="off", left="off", right="off", labelbottom='off')
    
    
    if maj_index == 0:
        ax.text(2003, 90, 'Women')
        ax.text(2005, 5, 'Men')
    elif maj_index == 5:
        ax.text(2005, 62, 'Men')
        ax.text(2003, 33, 'Women')
        ax.tick_params(labelbottom='on')
        
plt.show()

# %% [markdown]
# # Set y-axis Labels

# %%
fig = plt.figure(figsize=(16, 20))

for sp in range(0,18,3):
    maj_index = int(sp/3)
    ax = fig.add_subplot(6,3,sp+1)
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[maj_index]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[stem_cats[maj_index]], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(stem_cats[maj_index])
    ax.tick_params(bottom="off", top="off", left="off", right="off", labelbottom='off')
    ax.set_yticks([0,100])
    
    
    if sp == 0:
        ax.text(2005, 84, 'Women')
        ax.text(2007, 12, 'Men')
    elif sp == 15:
        ax.text(2007, 89, 'Men')
        ax.text(2005, 7, 'Women')
        ax.tick_params(labelbottom='on')


for sp in range(2,17,3):
    maj_index = int((sp-2)/3)
    ax = fig.add_subplot(6,3,sp)
    ax.plot(women_degrees['Year'], women_degrees[lib_arts_cats[maj_index]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[lib_arts_cats[maj_index]], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(lib_arts_cats[maj_index])
    ax.tick_params(bottom="off", top="off", left="off", right="off", labelbottom='off')
    ax.set_yticks([0,100])
    
    
    if maj_index == 0:
        ax.text(2005, 78, 'Women')
        ax.text(2007, 18, 'Men')
    elif maj_index == 4:
        ax.tick_params(labelbottom='on')
        
for sp in range(3,20,3):
    maj_index = int((sp-3) / 3)
    ax = fig.add_subplot(6,3,sp)
    ax.plot(women_degrees['Year'], women_degrees[other_cats[maj_index]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[other_cats[maj_index]], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(other_cats[maj_index])
    ax.tick_params(bottom="off", top="off", left="off", right="off", labelbottom='off')
    ax.set_yticks([0,100])
    
    
    if maj_index == 0:
        ax.text(2003, 90, 'Women')
        ax.text(2005, 5, 'Men')
    elif maj_index == 5:
        ax.text(2005, 62, 'Men')
        ax.text(2003, 33, 'Women')
        ax.tick_params(labelbottom='on')
        
plt.show()

# %% [markdown]
# # Adding a Horizontal Line and Saving Figure

# %%
fig = plt.figure(figsize=(16, 20))

for sp in range(0,18,3):
    maj_index = int(sp/3)
    ax = fig.add_subplot(6,3,sp+1)
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[maj_index]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[stem_cats[maj_index]], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(stem_cats[maj_index])
    ax.tick_params(bottom="off", top="off", left="off", right="off", labelbottom='off')
    ax.set_yticks([0,100])
    ax.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.5)
    
    if sp == 0:
        ax.text(2005, 84, 'Women')
        ax.text(2007, 12, 'Men')
    elif sp == 15:
        ax.text(2007, 89, 'Men')
        ax.text(2005, 7, 'Women')
        ax.tick_params(labelbottom='on')


for sp in range(2,17,3):
    maj_index = int((sp-2)/3)
    ax = fig.add_subplot(6,3,sp)
    ax.plot(women_degrees['Year'], women_degrees[lib_arts_cats[maj_index]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[lib_arts_cats[maj_index]], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(lib_arts_cats[maj_index])
    ax.tick_params(bottom="off", top="off", left="off", right="off", labelbottom='off')
    ax.set_yticks([0,100])
    ax.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.5)
    
    if maj_index == 0:
        ax.text(2005, 78, 'Women')
        ax.text(2007, 18, 'Men')
    elif maj_index == 4:
        ax.tick_params(labelbottom='on')
        
for sp in range(3,20,3):
    maj_index = int((sp-3) / 3)
    ax = fig.add_subplot(6,3,sp)
    ax.plot(women_degrees['Year'], women_degrees[other_cats[maj_index]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[other_cats[maj_index]], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(other_cats[maj_index])
    ax.tick_params(bottom="off", top="off", left="off", right="off", labelbottom='off')
    ax.set_yticks([0,100])
    ax.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.5)
    
    if maj_index == 0:
        ax.text(2003, 90, 'Women')
        ax.text(2005, 5, 'Men')
    elif maj_index == 5:
        ax.text(2005, 62, 'Men')
        ax.text(2003, 33, 'Women')
        ax.tick_params(labelbottom='on')

        
plt.savefig("gender_degrees.png")
plt.show()
